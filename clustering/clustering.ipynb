# %%
"""Fast k-means clustering."""
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots

from sklearn.cluster import KMeans

# Data
train_df = pd.read_csv("../data/train.csv", dtype={"Age": np.float64}, )
test_df = pd.read_csv("../data/test.csv", dtype={"Age": np.float64}, )
cols = ['PassengerId', 'Pclass']
# Out:
# /Users/jordanburgess/anaconda/envs/dl/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /Users/jordanburgess/anaconda/envs/dl/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /Users/jordanburgess/anaconda/envs/dl/lib/python2.7/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# ...

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
n_clusters = 8
# K-means++ is deafult with 300 iter
kmeans = KMeans(n_clusters=n_clusters)
train_clusters = kmeans.fit_predict(train_df[cols]);

# %%
predict_clusters = kmeans.predict(train_df[cols])

# %%
lda = LDA(n_components=2)
train_2d = lda.fit_transform(train_df[cols], train_clusters)

# %%
plt.plot(train_2d);
